# %%
pip install stable-baselines3[extra] gymnasium numpy matplotlib
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\praveena\myenv\lib\site-packages (2.5.0)
# Requirement already satisfied: gymnasium in c:\users\praveena\myenv\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy in c:\users\praveena\myenv\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\praveena\myenv\lib\site-packages (3.10.0)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\praveena\myenv\lib\site-packages (from stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: cloudpickle in c:\users\praveena\myenv\lib\site-packages (from stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: pandas in c:\users\praveena\myenv\lib\site-packages (from stable-baselines3[extra]) (2.2.3)
# Collecting opencv-python (from stable-baselines3[extra])
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Requirement already satisfied: pygame in c:\users\praveena\myenv\lib\site-packages (from stable-baselines3[extra]) (2.6.1)
# Collecting tensorboard>=2.9.1 (from stable-baselines3[extra])
#   Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: psutil in c:\users\praveena\myenv\lib\site-packages (from stable-baselines3[extra]) (6.0.0)
# Requirement already satisfied: tqdm in c:\users\praveena\myenv\lib\site-packages (from stable-baselines3[extra]) (4.66.5)
# Collecting rich (from stable-baselines3[extra])
#   Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Collecting ale-py>=0.9.0 (from stable-baselines3[extra])
#   Downloading ale_py-0.10.2-cp311-cp311-win_amd64.whl (1.5 MB)
#                                               0.0/1.5 MB ? eta -:--:--
#                                               0.0/1.5 MB 682.7 kB/s eta 0:00:03
#                                               0.0/1.5 MB 435.7 kB/s eta 0:00:04
#      -                                        0.1/1.5 MB 469.7 kB/s eta 0:00:04
#      ---                                      0.1/1.5 MB 731.4 kB/s eta 0:00:02
#      ---                                      0.1/1.5 MB 657.1 kB/s eta 0:00:03
#      -----                                    0.2/1.5 MB 737.3 kB/s eta 0:00:02
#      -----                                    0.2/1.5 MB 737.3 kB/s eta 0:00:02
#      -------                                  0.3/1.5 MB 820.5 kB/s eta 0:00:02
#      -------                                  0.3/1.5 MB 710.0 kB/s eta 0:00:02
#      --------                                 0.3/1.5 MB 679.5 kB/s eta 0:00:02
#      --------                                 0.3/1.5 MB 679.5 kB/s eta 0:00:02
#      ----------                               0.4/1.5 MB 715.8 kB/s eta 0:00:02
#      ----------                               0.4/1.5 MB 715.8 kB/s eta 0:00:02
#      -----------                              0.4/1.5 MB 689.4 kB/s eta 0:00:02
#      ------------                             0.5/1.5 MB 686.8 kB/s eta 0:00:02
#      -------------                            0.5/1.5 MB 713.7 kB/s eta 0:00:02
#      --------------                           0.5/1.5 MB 710.0 kB/s eta 0:00:02
#      --------------                           0.5/1.5 MB 710.0 kB/s eta 0:00:02
#      ---------------                          0.6/1.5 MB 655.6 kB/s eta 0:00:02
#      ---------------                          0.6/1.5 MB 655.6 kB/s eta 0:00:02
#      -----------------                        0.7/1.5 MB 699.7 kB/s eta 0:00:02
#      -----------------                        0.7/1.5 MB 699.7 kB/s eta 0:00:02
#      -----------------                        0.7/1.5 MB 699.7 kB/s eta 0:00:02
#      --------------------                     0.8/1.5 MB 703.9 kB/s eta 0:00:02
#      ---------------------                    0.8/1.5 MB 691.6 kB/s eta 0:00:01
#      -----------------------                  0.9/1.5 MB 724.6 kB/s eta 0:00:01
#      -------------------------                1.0/1.5 MB 763.4 kB/s eta 0:00:01
#      ---------------------------              1.0/1.5 MB 793.3 kB/s eta 0:00:01
#      ---------------------------              1.0/1.5 MB 789.5 kB/s eta 0:00:01
#      ----------------------------             1.1/1.5 MB 774.5 kB/s eta 0:00:01
#      -------------------------------          1.2/1.5 MB 819.5 kB/s eta 0:00:01
#      ----------------------------------       1.3/1.5 MB 862.5 kB/s eta 0:00:01
#      ------------------------------------     1.4/1.5 MB 889.6 kB/s eta 0:00:01
#      --------------------------------------   1.4/1.5 MB 902.0 kB/s eta 0:00:01
#      ---------------------------------------  1.5/1.5 MB 916.4 kB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 901.6 kB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\users\praveena\myenv\lib\site-packages (from stable-baselines3[extra]) (11.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\praveena\myenv\lib\site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\praveena\myenv\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\praveena\myenv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\praveena\myenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\praveena\myenv\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\praveena\myenv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\praveena\myenv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\praveena\myenv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\praveena\myenv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\praveena\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting absl-py>=0.4 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading absl_py-2.2.1-py3-none-any.whl (277 kB)
#                                               0.0/277.3 kB ? eta -:--:--
#      ----------                              71.7/277.3 kB 1.9 MB/s eta 0:00:01
#      ---------------------                  153.6/277.3 kB 1.8 MB/s eta 0:00:01
#      -------------------------              184.3/277.3 kB 1.4 MB/s eta 0:00:01
#      -------------------------              184.3/277.3 kB 1.4 MB/s eta 0:00:01
#      -------------------------              184.3/277.3 kB 1.4 MB/s eta 0:00:01
#      -------------------------              184.3/277.3 kB 1.4 MB/s eta 0:00:01
#      -------------------------              184.3/277.3 kB 1.4 MB/s eta 0:00:01
#      -------------------------              184.3/277.3 kB 1.4 MB/s eta 0:00:01
#      -----------------------------------  276.5/277.3 kB 654.2 kB/s eta 0:00:01
#      ------------------------------------ 277.3/277.3 kB 609.7 kB/s eta 0:00:00
# Collecting grpcio>=1.48.2 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading grpcio-1.71.0-cp311-cp311-win_amd64.whl (4.3 MB)
#                                               0.0/4.3 MB ? eta -:--:--
#                                               0.0/4.3 MB ? eta -:--:--
#                                               0.0/4.3 MB ? eta -:--:--
#      -                                        0.1/4.3 MB 819.2 kB/s eta 0:00:06
#      -                                        0.2/4.3 MB 984.6 kB/s eta 0:00:05
#      -                                        0.2/4.3 MB 841.6 kB/s eta 0:00:05
#      --                                       0.2/4.3 MB 1.0 MB/s eta 0:00:05
#      --                                       0.2/4.3 MB 1.0 MB/s eta 0:00:05
#      --                                       0.3/4.3 MB 714.4 kB/s eta 0:00:06
#      --                                       0.3/4.3 MB 759.5 kB/s eta 0:00:06
#      ---                                      0.4/4.3 MB 791.2 kB/s eta 0:00:05
#      ---                                      0.4/4.3 MB 825.1 kB/s eta 0:00:05
#      ----                                     0.4/4.3 MB 833.5 kB/s eta 0:00:05
#      ----                                     0.5/4.3 MB 885.8 kB/s eta 0:00:05
#      -----                                    0.6/4.3 MB 878.6 kB/s eta 0:00:05
#      -----                                    0.6/4.3 MB 909.2 kB/s eta 0:00:05
#      -----                                    0.6/4.3 MB 909.2 kB/s eta 0:00:05
#      ------                                   0.7/4.3 MB 855.6 kB/s eta 0:00:05
#      ------                                   0.7/4.3 MB 855.6 kB/s eta 0:00:05
#      ----------------------------------       3.7/4.3 MB 759.3 kB/s eta 0:00:01
#      ----------------------------------       3.7/4.3 MB 762.9 kB/s eta 0:00:01
#      ----------------------------------       3.7/4.3 MB 760.0 kB/s eta 0:00:01
#      -----------------------------------      3.8/4.3 MB 758.4 kB/s eta 0:00:01
#      -----------------------------------      3.8/4.3 MB 761.5 kB/s eta 0:00:01
#      ------------------------------------     3.9/4.3 MB 760.6 kB/s eta 0:00:01
#      ------------------------------------     3.9/4.3 MB 763.6 kB/s eta 0:00:01
#      ------------------------------------     3.9/4.3 MB 760.9 kB/s eta 0:00:01
#      -------------------------------------    4.0/4.3 MB 759.7 kB/s eta 0:00:01
#      -------------------------------------    4.0/4.3 MB 758.4 kB/s eta 0:00:01
#      -------------------------------------    4.1/4.3 MB 761.4 kB/s eta 0:00:01
#      --------------------------------------   4.1/4.3 MB 762.6 kB/s eta 0:00:01
#      --------------------------------------   4.1/4.3 MB 764.3 kB/s eta 0:00:01
#      --------------------------------------   4.1/4.3 MB 759.0 kB/s eta 0:00:01
#      --------------------------------------   4.2/4.3 MB 758.3 kB/s eta 0:00:01
#      ---------------------------------------  4.2/4.3 MB 763.0 kB/s eta 0:00:01
#      ---------------------------------------  4.3/4.3 MB 765.5 kB/s eta 0:00:01
#      ---------------------------------------  4.3/4.3 MB 765.5 kB/s eta 0:00:01
#      ---------------------------------------- 4.3/4.3 MB 757.3 kB/s eta 0:00:00
# Collecting markdown>=2.6.8 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading protobuf-6.30.2-cp310-abi3-win_amd64.whl (431 kB)
#                                               0.0/431.0 kB ? eta -:--:--
#      -----                                   61.4/431.0 kB 1.7 MB/s eta 0:00:01
#      ---------                              112.6/431.0 kB 1.1 MB/s eta 0:00:01
#      --------------                         163.8/431.0 kB 1.1 MB/s eta 0:00:01
#      -----------------                      194.6/431.0 kB 1.2 MB/s eta 0:00:01
#      -----------------                      194.6/431.0 kB 1.2 MB/s eta 0:00:01
#      ---------------------                256.0/431.0 kB 983.0 kB/s eta 0:00:01
#      -------------------------            307.2/431.0 kB 905.4 kB/s eta 0:00:01
#      -----------------------------        358.4/431.0 kB 928.4 kB/s eta 0:00:01
#      -------------------------------------  430.1/431.0 kB 1.0 MB/s eta 0:00:01
#      ------------------------------------ 431.0/431.0 kB 962.8 kB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\praveena\myenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (65.5.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\praveena\myenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.6)
# Requirement already satisfied: filelock in c:\users\praveena\myenv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.17.0)
# Requirement already satisfied: networkx in c:\users\praveena\myenv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\praveena\myenv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\praveena\myenv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\praveena\myenv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\praveena\myenv\lib\site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\praveena\myenv\lib\site-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\praveena\myenv\lib\site-packages (from pandas->stable-baselines3[extra]) (2025.1)
# Collecting markdown-it-py>=2.2.0 (from rich->stable-baselines3[extra])
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\praveena\myenv\lib\site-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: colorama in c:\users\praveena\myenv\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra])
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\praveena\myenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Installing collected packages: tensorboard-data-server, protobuf, opencv-python, mdurl, markdown, grpcio, ale-py, absl-py, tensorboard, markdown-it-py, rich
# Successfully installed absl-py-2.2.1 ale-py-0.10.2 grpcio-1.71.0 markdown-3.7 markdown-it-py-3.0.0 mdurl-0.1.2 opencv-python-4.11.0.86 protobuf-6.30.2 rich-13.9.4 tensorboard-2.19.0 tensorboard-data-server-0.7.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gymnasium as gym
import numpy as np
from gymnasium import spaces

class SpacecraftEnv(gym.Env):
    def __init__(self):
        super(SpacecraftEnv, self).__init__()
        
        # Continuous state space (position, velocity, angle, angular velocity)
        self.observation_space = spaces.Box(low=-1.0, high=1.0, shape=(4,), dtype=np.float32)

        # Continuous action space (thrust in X and Y directions)
        self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(2,), dtype=np.float32)
        
        self.state = np.zeros(4)  # [x, y, vx, vy]
        self.target = np.array([0.5, 0.5])  # Target position in space
        self.time_step = 0

    def step(self, action):
        thrust_x, thrust_y = action  # Continuous thrust in X and Y

        # Update spacecraft velocity with thrust
        self.state[2] += thrust_x * 0.01  # Small acceleration factor
        self.state[3] += thrust_y * 0.01

        # Update position with velocity
        self.state[0] += self.state[2]
        self.state[1] += self.state[3]

        # Compute distance to target
        distance = np.linalg.norm(self.state[:2] - self.target)
        
        # Reward function: Closer to target is better
        reward = -distance
        
        # Check if spacecraft reaches the target
        done = distance < 0.05 or self.time_step > 500

        self.time_step += 1
        return self.state, reward, done, False, {}

    def reset(self, seed=None, options=None):
        self.state = np.random.uniform(-1, 1, size=(4,))
        self.time_step = 0
        return self.state, {}

    def render(self):
        print(f"Position: {self.state[:2]}, Velocity: {self.state[2:]}")

# %%
from stable_baselines3 import SAC

# Create the environment
env = SpacecraftEnv()

# Train the agent using Soft Actor-Critic (SAC)
model = SAC("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=100000)

# Save the trained model
model.save("spacecraft_sac")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 502       |
# |    ep_rew_mean     | -1.74e+05 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 56        |
# |    time_elapsed    | 35        |
# |    total_timesteps | 2008      |
# | train/             |           |
# |    actor_loss      | 2.98e+03  |
# |    critic_loss     | 817       |
# |    ent_coef        | 0.846     |
# |    ent_coef_loss   | 0.635     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1907      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 502       |
# |    ep_rew_mean     | -1.31e+05 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 49        |
# |    time_elapsed    | 80        |
# |    total_timesteps | 4016      |
# | train/             |           |
# |    actor_loss      | 4.23e+03  |
# |    critic_loss     | 3.21e+03  |
# |    ent_coef        | 1.4       |
# |    ent_coef_loss   | -0.675    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3915      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 502       |
# |    ep_rew_mean     | -1.24e+05 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 47        |
# |    time_elapsed    | 126       |
# |    total_timesteps | 6024      |
# | train/             |           |
# |    actor_loss      | 5.45e+03  |
# |    critic_loss     | 3.77e+06  |
# |    ent_coef        | 1.94      |
# |    ent_coef_loss   | -0.401    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 5923      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 502       |
# |    ep_rew_mean     | -1.49e+05 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 33        |
# |    time_elapsed    | 240       |
# |    total_timesteps | 8032      |
# | train/             |           |
# |    actor_loss      | 9.4e+03   |
# |    critic_loss     | 1.73e+03  |
# |    ent_coef        | 1.66      |
# |    ent_coef_loss   | 0.0447    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7931      |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       6 # Train the agent using Soft Actor-Critic (SAC)
#       7 model = SAC("MlpPolicy", env, verbose=1)
# ----> 8 model.learn(total_timesteps=100000)
#      10 # Save the trained model
#      11 model.save("spacecraft_sac")
#
# File c:\Users\Praveena\myenv\Lib\site-packages\stable_baselines3\sac\sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File c:\Users\Praveena\myenv\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File c:\Users\Praveena\myenv\Lib\site-packages\stable_baselines3\sac\sac.py:281, in SAC.train(self, gradient_steps, batch_size)
#     279 self.actor.optimizer.zero_grad()
#     280 actor_loss.backward()
# --> 281 self.actor.optimizer.step()
#     283 # Update target networks
#     284 if gradient_step % self.target_update_interval == 0:
#
# File c:\Users\Praveena\myenv\Lib\site-packages\torch\optim\optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File c:\Users\Praveena\myenv\Lib\site-packages\torch\optim\optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File c:\Users\Praveena\myenv\Lib\site-packages\torch\optim\adam.py:244, in Adam.step(self, closure)
#     232     beta1, beta2 = group["betas"]
#     234     has_complex = self._init_group(
#     235         group,
#     236         params_with_grad,
#    (...)
#     241         state_steps,
#     242     )
# --> 244     adam(
#     245         params_with_grad,
#     246         grads,
#     247         exp_avgs,
#     248         exp_avg_sqs,
#     249         max_exp_avg_sqs,
#     250         state_steps,
#     251         amsgrad=group["amsgrad"],
#     252         has_complex=has_complex,
#     253         beta1=beta1,
#     254         beta2=beta2,
#     255         lr=group["lr"],
#     256         weight_decay=group["weight_decay"],
#     257         eps=group["eps"],
#     258         maximize=group["maximize"],
#     259         foreach=group["foreach"],
#     260         capturable=group["capturable"],
#     261         differentiable=group["differentiable"],
#     262         fused=group["fused"],
#     263         grad_scale=getattr(self, "grad_scale", None),
#     264         found_inf=getattr(self, "found_inf", None),
#     265     )
#     267 return loss
#
# File c:\Users\Praveena\myenv\Lib\site-packages\torch\optim\optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File c:\Users\Praveena\myenv\Lib\site-packages\torch\optim\adam.py:876, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     873 else:
#     874     func = _single_tensor_adam
# --> 876 func(
#     877     params,
#     878     grads,
#     879     exp_avgs,
#     880     exp_avg_sqs,
#     881     max_exp_avg_sqs,
#     882     state_steps,
#     883     amsgrad=amsgrad,
#     884     has_complex=has_complex,
#     885     beta1=beta1,
#     886     beta2=beta2,
#     887     lr=lr,
#     888     weight_decay=weight_decay,
#     889     eps=eps,
#     890     maximize=maximize,
#     891     capturable=capturable,
#     892     differentiable=differentiable,
#     893     grad_scale=grad_scale,
#     894     found_inf=found_inf,
#     895 )
#
# File c:\Users\Praveena\myenv\Lib\site-packages\torch\optim\adam.py:423, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     420     device_beta1 = beta1
#     422 # Decay the first and second moment running average coefficient
# --> 423 exp_avg.lerp_(grad, 1 - device_beta1)
#     425 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     427 if capturable or differentiable:
#
# KeyboardInterrupt:
