# %%
import gym 
import time 
import matplotlib.pyplot as plt 
# Create the environment with human render mode 
env = gym.make("CartPole-v1", render_mode="human") 
env.reset() 
# Sample a random action 
randomAction = env.action_space.sample() 
# Take a step in the environment with the random action 
returnValue = env.step(randomAction) 
# Render the environment 
env.render()

# %%
# Create the environment with RGB array render mode 
env = gym.make("CartPole-v1", render_mode="rgb_array") 
env.reset() 
# Access the observation space 
print(env.observation_space) 
# Render the environment to get an image 
img = env.render() 
# Display the image using matplotlib 
plt.imshow(img) 
plt.show() 
# Print the observation and action spaces 
print(env.observation_space) 
print(env.action_space)
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# Discrete(2)

# %%
# Create the environment with RGB array render mode 
env = gym.make("CartPole-v1", render_mode="rgb_array") 
observation = env.reset() 
# Define a custom initial state 
custom_initial_state = [1, 1, 2, 1] 
# Set the environment's state to the custom initial state env.state = custom_initial_state 
# Render the environment to get an image 
img = env.render()
# Display the image using matplotlib 
plt.imshow(img) 
plt.show()

# %%
# Create the environment with human render mode 
env = gym.make("CartPole-v1", render_mode='human') 
env.reset() 
env.render() 
print('Initial state of the system') 
# Define the number of iterations 
numberOfIterations = 10 
# Loop through the defined number of iterations 
for i in range(numberOfIterations): 
 # Sample a random action 
 randomAction = env.action_space.sample() 
 # Take a step in the environment with the random action  returnValue = env.step(randomAction) 
 # Render the environment 
 env.render() 
 print('Iteration : {} Action : {}'.format(i + 1, randomAction)) 
 # Pause for 2 seconds 
 time.sleep(2) 
 # Check if the episode has ended 
 if returnValue[2]: 
    break 
# Close the environment 
env.close()
# Out:
# Initial state of the system
# Iteration : 1 Action : 0
# Iteration : 2 Action : 0
# Iteration : 3 Action : 0
# Iteration : 4 Action : 0
# Iteration : 5 Action : 1
# Iteration : 6 Action : 0
# Iteration : 7 Action : 0
# Iteration : 8 Action : 1
# Iteration : 9 Action : 0
# Iteration : 10 Action : 0
